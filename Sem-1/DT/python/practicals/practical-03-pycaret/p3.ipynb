# %% [markdown]
# ### Experiment 4: Build a classification model by using different machine learning algorithms.
#
# ## Software Used: Google colaboratory---
# # **PyCaret for Classification**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self Learning Resource**
# 1. Tutorial on Pycaret <a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>
#
# 2. Documentation on Pycaret-Classification: <a href="https://pycaret.org/Classification/"> Click Here </a>
#
# ---
#
# ### **In this experiment we will learn:**
#
# - Getting Data: How to import data from PyCaret repository
# - Setting up Environment: How to setup an experiment in PyCaret and get started with building regression models
# - Create Model: How to create a model, perform cross validation and evaluate regression metrics
# - Tune Model: How to automatically tune the hyperparameters of a regression model
# - Plot Model: How to analyze model performance using various plots
# - Finalize Model: How to finalize the best model at the end of the experiment
# - Predict Model: How to make prediction on new / unseen data
# - Save / Load Model: How to save / load a model for future use
#
# ---

# %% [markdown]
# #### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# #### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.1'

# %% [markdown]
# ---
# # **1. Classification: Basics**
# ---

# %% [markdown]
# ### **1.1 Loading Dataset - Loading dataset from pycaret**

# %%
from pycaret.datasets import get_data

# No output

# %% [markdown]
# ---
# ### **1.2 Get the list of datasets available in pycaret (55)**
# ---

# %%
# Internet connection is required
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# 10                             heart  Multivariate  ...           16              N
# 11                     heart_disease  Multivariate  ...           14              N
# 12                         hepatitis  Multivariate  ...           32              Y
# 13                            income  Multivariate  ...           14              Y
# 14                             juice  Multivariate  ...           15              N
# 15                               nba  Multivariate  ...           21              N
# 16                              wine  Multivariate  ...           13              N
# 17                         telescope  Multivariate  ...           11              N
# 18                           titanic  Multivariate  ...           11              Y
# 19  us_presidential_election_results  Multivariate  ...            7              N
# 20                             glass  Multivariate  ...           10              N
# 21                              iris  Multivariate  ...            5              N
# 22                             poker  Multivariate  ...           11              N
# 23                         questions  Multivariate  ...            4              N
# 24                         satellite  Multivariate  ...           37              N
# 25                               CTG  Multivariate  ...           40              Y
# 26                          asia_gdp  Multivariate  ...           11              N
# 27                         elections  Multivariate  ...           54              Y
# 28                          facebook  Multivariate  ...           12              N
# 29                               ipl  Multivariate  ...           25              N
# 30                         jewellery  Multivariate  ...            4              N
# 31                              mice  Multivariate  ...           82              Y
# 32                         migration  Multivariate  ...           12              N
# 33                           perfume  Multivariate  ...           29              N
# 34                           pokemon  Multivariate  ...           13              Y
# 35                        population  Multivariate  ...           56              Y
# 36                     public_health  Multivariate  ...           21              N
# 37                             seeds  Multivariate  ...            7              N
# 38                         wholesale  Multivariate  ...            8              N
# 39                            tweets          Text  ...            2              N
# 40                            amazon          Text  ...            2              N
# 41                              kiva          Text  ...            7              N
# 42                               spx          Text  ...            4              N
# 43                         wikipedia          Text  ...            3              N
# 44                        automobile  Multivariate  ...           26              Y
# 45                              bike  Multivariate  ...           15              N
# 46                            boston  Multivariate  ...           14              N
# 47                          concrete  Multivariate  ...            9              N
# 48                           diamond  Multivariate  ...            8              N
# 49                            energy  Multivariate  ...           10              N
# 50                            forest  Multivariate  ...           13              N
# 51                              gold  Multivariate  ...          121              N
# 52                             house  Multivariate  ...           81              Y
# 53                         insurance  Multivariate  ...            7              N
# 54                        parkinsons  Multivariate  ...           22              N
# 55                           traffic  Multivariate  ...            8              N
#
# [56 rows x 8 columns]

# %% [markdown]
# ---
# ### **1.3 Get diabetes dataset**
# ---

# %%
diabetesDataSet = get_data("diabetes")    # SN is 7
# This is binary classification dataset. The values in "Class variable" have two (binary) values.
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %% [markdown]
# Read data from file

# %%
# import pandas as pd
# diabetesDataSet = pd.read_csv("myFile.csv")

# %% [markdown]
# ---
# ### **1.4 Parameter setting for all classification models**
# - Train/Test division
# - Sampling
# - Normalization
# - Transformation
# - PCA (Dimention Reduction)
# - Handaling of Outliers
# - Feature Selection
# ---

# %%
from pycaret.classification import *
s = setup(data=diabetesDataSet, target='Class variable', silent=True)

# %% [markdown]
# ---
# ### **1.5 Run and compare the Model Performance**
# ---

# %%
cm = compare_models()
# Explore more parameters
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7580  0.7945  0.5889  0.7104
# lr                    Logistic Regression    0.7505  0.7970  0.5324  0.7206
# ridge                    Ridge Classifier    0.7486  0.0000  0.5174  0.7255
# lda          Linear Discriminant Analysis    0.7486  0.7940  0.5174  0.7241
# gbc          Gradient Boosting Classifier    0.7376  0.8136  0.5584  0.6812
# et                 Extra Trees Classifier    0.7376  0.7846  0.5234  0.6975
# ada                  Ada Boost Classifier    0.7282  0.7929  0.5982  0.6434
# lightgbm  Light Gradient Boosting Machine    0.7209  0.7852  0.5889  0.6445
# knn                K Neighbors Classifier    0.6907  0.7115  0.5166  0.5920
# dt               Decision Tree Classifier    0.6742  0.6473  0.5476  0.5647
# nb                            Naive Bayes    0.6667  0.7378  0.1724  0.6939
# svm                   SVM - Linear Kernel    0.5512  0.0000  0.4716  0.4242
# qda       Quadratic Discriminant Analysis    0.5421  0.5887  0.5661  0.4382
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6415  0.4614  0.4678     0.506
# lr        0.6083  0.4317  0.4447     0.470
# ridge     0.5993  0.4243  0.4398     0.013
# lda       0.5986  0.4239  0.4393     0.016
# gbc       0.6079  0.4145  0.4229     0.121
# et        0.5904  0.4049  0.4181     0.459
# ada       0.6168  0.4070  0.4101     0.104
# lightgbm  0.6073  0.3929  0.3995     0.093
# knn       0.5486  0.3158  0.3192     0.114
# dt        0.5533  0.2974  0.2994     0.016
# nb        0.2665  0.1472  0.2073     0.015
# svm       0.3817  0.0695  0.0580     0.015
# qda       0.4323  0.0920  0.1082     0.015

# %% [markdown]
# ---
# ### **1.6 Three line of code for model comparison for "Cancer" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

cancerDataSet = get_data("cancer")
s = setup(data = cancerDataSet, target='Class', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# svm                   SVM - Linear Kernel    0.9707  0.0000  0.9574  0.9601
# rf               Random Forest Classifier    0.9707  0.9960  0.9632  0.9552
# lr                    Logistic Regression    0.9665  0.9967  0.9574  0.9490
# ada                  Ada Boost Classifier    0.9664  0.9969  0.9445  0.9610
# nb                            Naive Bayes    0.9644  0.9815  0.9629  0.9387
# et                 Extra Trees Classifier    0.9644  0.9954  0.9449  0.9546
# lightgbm  Light Gradient Boosting Machine    0.9624  0.9949  0.9515  0.9445
# ridge                    Ridge Classifier    0.9602  0.0000  0.9265  0.9575
# gbc          Gradient Boosting Classifier    0.9561  0.9940  0.9331  0.9441
# lda          Linear Discriminant Analysis    0.9539  0.9915  0.9143  0.9505
# knn                K Neighbors Classifier    0.9477  0.9771  0.8787  0.9671
# dt               Decision Tree Classifier    0.9226  0.9118  0.8776  0.9006
# qda       Quadratic Discriminant Analysis    0.8851  0.9113  0.9938  0.7596
#
#               F1   Kappa     MCC  TT (Sec)
# svm       0.9577  0.9353  0.9365     0.015
# rf        0.9572  0.9350  0.9372     0.477
# lr        0.9515  0.9260  0.9278     0.275
# ada       0.9496  0.9245  0.9278     0.107
# nb        0.9492  0.9218  0.9236     0.016
# et        0.9477  0.9208  0.9229     0.464
# lightgbm  0.9464  0.9175  0.9193     0.089
# ridge     0.9402  0.9104  0.9123     0.016
# gbc       0.9359  0.9026  0.9055     0.119
# lda       0.9305  0.8961  0.8982     0.024
# knn       0.9197  0.8811  0.8844     0.122
# dt        0.8861  0.8276  0.8308     0.017
# qda       0.8585  0.7662  0.7882     0.020

# %% [markdown]
# ---
# ### **1.7 Three line of code for model comparison for "Heart Disease" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

heartDiseaseDataSet = get_data("heart_disease")
s = setup(data = heartDiseaseDataSet, target='Disease', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.8418  0.8963  0.7982  0.8394
# lr                    Logistic Regression    0.8412  0.9050  0.8107  0.8245
# et                 Extra Trees Classifier    0.8409  0.8911  0.7821  0.8478
# lightgbm  Light Gradient Boosting Machine    0.8351  0.8951  0.8089  0.8120
# ridge                    Ridge Classifier    0.8307  0.0000  0.7964  0.8152
# lda          Linear Discriminant Analysis    0.8307  0.8948  0.7964  0.8152
# gbc          Gradient Boosting Classifier    0.8249  0.8739  0.7571  0.8153
# nb                            Naive Bayes    0.7980  0.8830  0.8964  0.7261
# ada                  Ada Boost Classifier    0.7760  0.8347  0.7054  0.7554
# dt               Decision Tree Classifier    0.7664  0.7632  0.7446  0.7061
# knn                K Neighbors Classifier    0.6558  0.6779  0.5143  0.6666
# qda       Quadratic Discriminant Analysis    0.5749  0.5216  0.2250  0.3503
# svm                   SVM - Linear Kernel    0.5424  0.0000  0.3821  0.3648
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.8124  0.6760  0.6833     0.464
# lr        0.8120  0.6751  0.6818     0.215
# et        0.8067  0.6719  0.6812     0.460
# lightgbm  0.8059  0.6637  0.6691     0.028
# ridge     0.7995  0.6531  0.6600     0.014
# lda       0.7995  0.6531  0.6600     0.015
# gbc       0.7826  0.6363  0.6403     0.082
# nb        0.7924  0.6040  0.6331     0.015
# ada       0.7238  0.5365  0.5435     0.092
# dt        0.7227  0.5210  0.5244     0.016
# knn       0.5653  0.2841  0.3019     0.117
# qda       0.2141  0.0424  0.0521     0.015
# svm       0.3116  0.0475  0.0601     0.017

# %% [markdown]
# ---
# # **2. Classification: Advance - 1**
# ---

# %% [markdown]
# #### **2.1 Model Performance using data "Normalization"**

# %% [markdown]
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information.

# %%
## Commonly used techniques: clipping, log scaling, z-score, minmax, maxabs, robust
s = setup(data=diabetesDataSet, target='Class variable', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7689  0.8156  0.5310  0.7122
# ridge                    Ridge Classifier    0.7652  0.0000  0.5255  0.7138
# gbc          Gradient Boosting Classifier    0.7579  0.8225  0.5647  0.6559
# lda          Linear Discriminant Analysis    0.7559  0.8123  0.5255  0.6909
# lightgbm  Light Gradient Boosting Machine    0.7523  0.8127  0.5869  0.6379
# rf               Random Forest Classifier    0.7468  0.8042  0.4977  0.6563
# knn                K Neighbors Classifier    0.7450  0.7424  0.5147  0.6508
# ada                  Ada Boost Classifier    0.7393  0.7861  0.5709  0.6191
# et                 Extra Trees Classifier    0.7281  0.7889  0.4248  0.6438
# svm                   SVM - Linear Kernel    0.7057  0.0000  0.5209  0.5871
# dt               Decision Tree Classifier    0.6744  0.6376  0.5261  0.5163
# nb                            Naive Bayes    0.6703  0.7179  0.1121  0.6310
# qda       Quadratic Discriminant Analysis    0.5268  0.5511  0.5000  0.4310
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.5968  0.4428  0.4586     0.271
# ridge     0.5908  0.4342  0.4524     0.014
# gbc       0.6029  0.4318  0.4366     0.120
# lda       0.5814  0.4164  0.4332     0.017
# lightgbm  0.6074  0.4282  0.4315     0.094
# rf        0.5524  0.3863  0.3990     0.511
# knn       0.5615  0.3899  0.4003     0.119
# ada       0.5868  0.3992  0.4043     0.106
# et        0.5067  0.3313  0.3470     0.462
# svm       0.5333  0.3252  0.3379     0.015
# dt        0.5179  0.2734  0.2755     0.016
# nb        0.1824  0.0776  0.1328     0.017
# qda       0.3406  0.0424  0.0589     0.017

# %% [markdown]
# ---
# ### **2.2 Model Performance using "Feature Selection"**
# ---

# %% [markdown]
# Feature Selection is one of the core concepts in machine learning which hugely impacts the performance of your model. The data features that you use to train your machine learning models have a huge influence on the performance you can achieve. The goal of feature selection in machine learning is to find the best set of features that allows one to build useful models of studied phenomena. Threshold used for feature selection (including newly created polynomial features). A higher value will result in a higher feature space. It is recommended to do multiple trials with different values of feature_selection_threshold.

# %%
s = setup(data=diabetesDataSet, target='Class variable', feature_selection = True, feature_selection_threshold = 0.6, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7820  0.8187  0.5807  0.7553
# lda          Linear Discriminant Analysis    0.7819  0.8142  0.5863  0.7503
# ridge                    Ridge Classifier    0.7800  0.0000  0.5807  0.7486
# rf               Random Forest Classifier    0.7690  0.8294  0.5754  0.7304
# lightgbm  Light Gradient Boosting Machine    0.7596  0.8111  0.5915  0.6914
# gbc          Gradient Boosting Classifier    0.7560  0.8196  0.5696  0.6849
# ada                  Ada Boost Classifier    0.7503  0.8136  0.5921  0.6722
# knn                K Neighbors Classifier    0.7375  0.7533  0.5418  0.6467
# et                 Extra Trees Classifier    0.7374  0.8036  0.4886  0.6833
# nb                            Naive Bayes    0.6982  0.7491  0.3029  0.6462
# dt               Decision Tree Classifier    0.6980  0.6670  0.5693  0.5648
# qda       Quadratic Discriminant Analysis    0.6183  0.6657  0.4465  0.4382
# svm                   SVM - Linear Kernel    0.5494  0.0000  0.5231  0.4748
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6460  0.4932  0.5098     0.209
# lda       0.6470  0.4939  0.5100     0.016
# ridge     0.6437  0.4893  0.5050     0.014
# rf        0.6306  0.4672  0.4837     0.513
# lightgbm  0.6289  0.4536  0.4635     0.046
# gbc       0.6147  0.4393  0.4481     0.119
# ada       0.6198  0.4365  0.4461     0.103
# knn       0.5828  0.3947  0.4021     0.120
# et        0.5597  0.3804  0.3977     0.462
# nb        0.4035  0.2353  0.2706     0.015
# dt        0.5646  0.3341  0.3357     0.016
# qda       0.3870  0.1473  0.1692     0.015
# svm       0.3797  0.0892  0.1052     0.017

# %% [markdown]
# ---
# ### **2.3 Model Performance using "Outlier Removal"**
# ---

# %% [markdown]
# Sometimes a dataset can contain extreme values that are outside the range of what is expected and unlike the other data. These are called outliers and often machine learning modeling and model skill in general can be improved by understanding and even removing these outlier values. outliers_threshold = 0.05 is the default value.

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7745  0.8287  0.5647  0.7058
# lr                    Logistic Regression    0.7686  0.8272  0.5588  0.6927
# gbc          Gradient Boosting Classifier    0.7686  0.8209  0.6000  0.6842
# lda          Linear Discriminant Analysis    0.7627  0.8275  0.5412  0.6822
# ridge                    Ridge Classifier    0.7608  0.0000  0.5235  0.6870
# ada                  Ada Boost Classifier    0.7529  0.7839  0.5882  0.6512
# et                 Extra Trees Classifier    0.7529  0.8123  0.5176  0.6758
# knn                K Neighbors Classifier    0.7314  0.7798  0.5647  0.6045
# lightgbm  Light Gradient Boosting Machine    0.7275  0.8071  0.5412  0.6075
# nb                            Naive Bayes    0.7157  0.7654  0.6941  0.5638
# dt               Decision Tree Classifier    0.7000  0.6574  0.5294  0.5496
# svm                   SVM - Linear Kernel    0.5922  0.0000  0.5294  0.4270
# qda       Quadratic Discriminant Analysis    0.4667  0.6360  0.7294  0.3633
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6240  0.4663  0.4746     0.498
# lr        0.6133  0.4522  0.4610     0.205
# gbc       0.6315  0.4651  0.4732     0.119
# lda       0.6001  0.4357  0.4438     0.016
# ridge     0.5897  0.4265  0.4372     0.014
# ada       0.6106  0.4318  0.4386     0.104
# et        0.5785  0.4097  0.4214     0.460
# knn       0.5776  0.3830  0.3875     0.115
# lightgbm  0.5652  0.3696  0.3759     0.046
# nb        0.6185  0.3969  0.4063     0.015
# dt        0.5369  0.3163  0.3175     0.016
# svm       0.4301  0.1392  0.1634     0.015
# qda       0.4468  0.0542  0.0620     0.014

# %% [markdown]
# ---
# ### **2.4 Model Performance using "Transformation"**
# ---

# %% [markdown]
# Data transformation is the process in which you take data from its raw, siloed and normalized source state and transform it into data that's joined together, dimensionally modeled, de-normalized, and ready for analysis

# %%
s = setup(data=diabetesDataSet, target='Class variable', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7619  0.8259  0.5995  0.7401
# lda          Linear Discriminant Analysis    0.7526  0.8226  0.5895  0.7253
# gbc          Gradient Boosting Classifier    0.7507  0.8057  0.5987  0.7053
# ridge                    Ridge Classifier    0.7471  0.0000  0.5795  0.7171
# lightgbm  Light Gradient Boosting Machine    0.7451  0.8001  0.6089  0.6791
# ada                  Ada Boost Classifier    0.7358  0.8092  0.6245  0.6678
# svm                   SVM - Linear Kernel    0.7283  0.0000  0.5845  0.6499
# rf               Random Forest Classifier    0.7283  0.8112  0.5384  0.6701
# knn                K Neighbors Classifier    0.7281  0.7626  0.5134  0.6780
# dt               Decision Tree Classifier    0.7209  0.7002  0.6192  0.6142
# et                 Extra Trees Classifier    0.7041  0.7748  0.5032  0.6439
# nb                            Naive Bayes    0.6332  0.7204  0.0508  0.4000
# qda       Quadratic Discriminant Analysis    0.5346  0.5593  0.6976  0.4667
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6498  0.4741  0.4881     0.025
# lda       0.6359  0.4537  0.4684     0.016
# gbc       0.6427  0.4533  0.4606     0.117
# ridge     0.6266  0.4407  0.4554     0.015
# lightgbm  0.6375  0.4430  0.4478     0.049
# ada       0.6372  0.4311  0.4379     0.104
# svm       0.6063  0.4026  0.4104     0.018
# rf        0.5932  0.3939  0.4015     0.504
# knn       0.5816  0.3868  0.3965     0.116
# dt        0.6112  0.3961  0.3988     0.016
# et        0.5583  0.3417  0.3515     0.465
# nb        0.0858  0.0327  0.0523     0.016
# qda       0.5136  0.1268  0.1636     0.015

# %% [markdown]
# ---
# ### **2.5 Model Performance using "PCA"**
# ---

# %% [markdown]
# An important machine learning method for dimensionality reduction is called Principal Component Analysis. It is a method that uses simple matrix operations from linear algebra and statistics to calculate a projection of the original data into the same number or fewer dimensions.

# %%
s = setup(data=diabetesDataSet, target='Class variable', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.7673  0.0000  0.5137  0.7351
# lda          Linear Discriminant Analysis    0.7654  0.8171  0.5243  0.7262
# lr                    Logistic Regression    0.7636  0.8162  0.5243  0.7239
# rf               Random Forest Classifier    0.7597  0.8129  0.5725  0.6909
# dt               Decision Tree Classifier    0.7561  0.7287  0.6415  0.6548
# et                 Extra Trees Classifier    0.7559  0.8187  0.5617  0.6811
# ada                  Ada Boost Classifier    0.7523  0.7920  0.5833  0.6672
# qda       Quadratic Discriminant Analysis    0.7522  0.8112  0.5287  0.6902
# nb                            Naive Bayes    0.7466  0.8048  0.5453  0.6697
# gbc          Gradient Boosting Classifier    0.7373  0.8035  0.5728  0.6396
# knn                K Neighbors Classifier    0.7337  0.7747  0.5406  0.6415
# lightgbm  Light Gradient Boosting Machine    0.7337  0.7995  0.6006  0.6280
# svm                   SVM - Linear Kernel    0.6759  0.0000  0.5494  0.5340
#
#               F1   Kappa     MCC  TT (Sec)
# ridge     0.5997  0.4443  0.4614     0.013
# lda       0.6034  0.4441  0.4595     0.016
# lr        0.6021  0.4409  0.4566     0.021
# rf        0.6206  0.4479  0.4560     0.513
# dt        0.6425  0.4587  0.4630     0.016
# et        0.6131  0.4376  0.4438     0.464
# ada       0.6185  0.4370  0.4422     0.102
# qda       0.5888  0.4182  0.4319     0.015
# nb        0.5915  0.4127  0.4235     0.015
# gbc       0.5993  0.4058  0.4112     0.117
# knn       0.5831  0.3904  0.3960     0.116
# lightgbm  0.6095  0.4089  0.4124     0.052
# svm       0.5353  0.2897  0.2926     0.017

# %% [markdown]
# ---
# ### **2.6 Model Performance using "Outlier Removal" + "Normalization"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7686  0.8175  0.5755  0.7145
# ridge                    Ridge Classifier    0.7667  0.0000  0.5699  0.7098
# lda          Linear Discriminant Analysis    0.7647  0.8136  0.5699  0.7038
# rf               Random Forest Classifier    0.7569  0.8171  0.5588  0.6944
# gbc          Gradient Boosting Classifier    0.7510  0.8164  0.5928  0.6672
# ada                  Ada Boost Classifier    0.7451  0.8023  0.5876  0.6514
# lightgbm  Light Gradient Boosting Machine    0.7451  0.8040  0.6258  0.6429
# knn                K Neighbors Classifier    0.7333  0.7699  0.5474  0.6505
# et                 Extra Trees Classifier    0.7333  0.8044  0.5186  0.6466
# svm                   SVM - Linear Kernel    0.6980  0.0000  0.4686  0.5890
# nb                            Naive Bayes    0.6922  0.7463  0.4745  0.5693
# dt               Decision Tree Classifier    0.6706  0.6437  0.5533  0.5273
# qda       Quadratic Discriminant Analysis    0.5000  0.5380  0.6310  0.3905
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6307  0.4672  0.4771     0.022
# ridge     0.6272  0.4621  0.4711     0.014
# lda       0.6249  0.4582  0.4664     0.016
# rf        0.6150  0.4414  0.4496     0.503
# gbc       0.6224  0.4391  0.4443     0.116
# ada       0.6128  0.4254  0.4301     0.103
# lightgbm  0.6304  0.4370  0.4400     0.048
# knn       0.5876  0.3940  0.4020     0.116
# et        0.5734  0.3839  0.3898     0.463
# svm       0.5061  0.2997  0.3094     0.014
# nb        0.5151  0.2938  0.2974     0.015
# dt        0.5317  0.2810  0.2864     0.016
# qda       0.4348  0.0566  0.0534     0.015

# %% [markdown]
# ---
# ### **2.7 Model Performance using "Outlier Removal" + "Normalization" + "Transformation"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ada                  Ada Boost Classifier    0.7471  0.7826  0.5471  0.6620
# lr                    Logistic Regression    0.7431  0.8059  0.5000  0.6535
# gbc          Gradient Boosting Classifier    0.7431  0.7908  0.5294  0.6412
# lda          Linear Discriminant Analysis    0.7353  0.7998  0.4765  0.6406
# rf               Random Forest Classifier    0.7333  0.7757  0.4588  0.6517
# ridge                    Ridge Classifier    0.7314  0.0000  0.4588  0.6377
# et                 Extra Trees Classifier    0.7235  0.7460  0.3882  0.6389
# knn                K Neighbors Classifier    0.7176  0.7126  0.4235  0.6116
# nb                            Naive Bayes    0.7078  0.7247  0.4588  0.5680
# lightgbm  Light Gradient Boosting Machine    0.7000  0.7566  0.5059  0.5527
# svm                   SVM - Linear Kernel    0.6902  0.0000  0.5059  0.5484
# dt               Decision Tree Classifier    0.6667  0.6250  0.5000  0.4913
# qda       Quadratic Discriminant Analysis    0.6588  0.6509  0.3882  0.5124
#
#               F1   Kappa     MCC  TT (Sec)
# ada       0.5884  0.4093  0.4200     0.104
# lr        0.5585  0.3843  0.3954     0.022
# gbc       0.5770  0.3957  0.4012     0.117
# lda       0.5397  0.3617  0.3729     0.016
# rf        0.5314  0.3541  0.3685     0.511
# ridge     0.5266  0.3483  0.3609     0.013
# et        0.4782  0.3077  0.3268     0.461
# knn       0.4942  0.3098  0.3223     0.119
# nb        0.5039  0.3031  0.3073     0.015
# lightgbm  0.5216  0.3064  0.3107     0.050
# svm       0.5136  0.2914  0.2988     0.016
# dt        0.4929  0.2459  0.2473     0.016
# qda       0.4059  0.1893  0.2018     0.017

# %% [markdown]
# **Task:** Use different machine learning models to classify a dataset and use classification based Model Evaluation Parameters for performance analysis.
